# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import random as r
x=np.linspace(0,10,100)
y=x
e=2.66
z=1/(1+np.exp(-e*x))
r=np.random.rand(len(x))
# (y−x 2/3 ) 2 =5

# plt.scatter(x,y,color='red')
# plt.scatter(x,r,color='blue')
plt.scatter(x,y)
plt.scatter(x,z,color='green')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
levels = np.linspace(Z.min(), Z.max(), 7)

# plot
fig, ax = plt.subplots()

ax.contourf(X, Y, Z, levels=levels)

plt.show()

# %%
x=np.linspace(0,10,100)
r1=np.random.rand(len(x))
y=x+r1

plt.scatter(x,y)

# %%
c=pd.read_csv('./archive/SOCR-HeightWeight.csv')
h=np.array(c['Hgt'])
w=np.array(c['Wgt'])
m=np.mean(h)
a=np.array([])
b=np.array([])


plt.scatter(h,w,marker='+')
plt.scatter(a,b)
